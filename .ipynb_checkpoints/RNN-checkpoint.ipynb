# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
movies=pd.read_csv('train_file_prediction.csv',sep=';')
movies.shape
# Out:
# (4499, 48)

# %%
liste_colonnes=list(movies.columns)
liste_colonnes.remove('imdb_score')
X=movies[liste_colonnes]
y=movies['imdb_score']

# %%
def baseline_model():
    # create model
    model = Sequential()
    model.add(Dense(250, input_dim=47, activation='relu'))
    model.add(Dense(100, activation='tanh'))
    #model.add(Dropout(0.3))
    model.add(Dense(40, activation='relu'))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(1))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam',metrics=['accuracy','mean_squared_error'])
    return model

# %%
#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
model=baseline_model()

history = model.fit(X, y, batch_size=128, epochs=20)
plt.plot(history.history['mean_squared_error'])
# Out:
# Epoch 1/20
# 36/36 [==============================] - 1s 2ms/step - loss: 11.4354 - accuracy: 0.0000e+00 - mean_squared_error: 11.4354
# Epoch 2/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.3185 - accuracy: 0.0000e+00 - mean_squared_error: 1.3185
# Epoch 3/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2860 - accuracy: 0.0000e+00 - mean_squared_error: 1.2860
# Epoch 4/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.3546 - accuracy: 0.0000e+00 - mean_squared_error: 1.3546
# Epoch 5/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.3100 - accuracy: 0.0000e+00 - mean_squared_error: 1.3100
# Epoch 6/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.3138 - accuracy: 0.0000e+00 - mean_squared_error: 1.3138
# Epoch 7/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.3319 - accuracy: 0.0000e+00 - mean_squared_error: 1.3319
# Epoch 8/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2677 - accuracy: 0.0000e+00 - mean_squared_error: 1.2677
# Epoch 9/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2725 - accuracy: 0.0000e+00 - mean_squared_error: 1.2725
# Epoch 10/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2976 - accuracy: 0.0000e+00 - mean_squared_error: 1.2976
# Epoch 11/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2816 - accuracy: 0.0000e+00 - mean_squared_error: 1.2816
# Epoch 12/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2610 - accuracy: 0.0000e+00 - mean_squared_error: 1.2610
# Epoch 13/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2721 - accuracy: 0.0000e+00 - mean_squared_error: 1.2721
# Epoch 14/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2274 - accuracy: 0.0000e+00 - mean_squared_error: 1.2274
# Epoch 15/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2629 - accuracy: 0.0000e+00 - mean_squared_error: 1.2629
# Epoch 16/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.1984 - accuracy: 0.0000e+00 - mean_squared_error: 1.1984
# Epoch 17/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2261 - accuracy: 0.0000e+00 - mean_squared_error: 1.2261
# Epoch 18/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2797 - accuracy: 0.0000e+00 - mean_squared_error: 1.2797
# Epoch 19/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.2132 - accuracy: 0.0000e+00 - mean_squared_error: 1.2132
# Epoch 20/20
# 36/36 [==============================] - 0s 2ms/step - loss: 1.3024 - accuracy: 0.0000e+00 - mean_squared_error: 1.3024

# %%
y_pred = model.predict(X_test)
y_pred=np.around(y_pred, decimals=2)
model.evaluate(X_test, y_test)
# Out:
# 29/29 [==============================] - 0s 1ms/step - loss: 1.4070 - accuracy: 0.0000e+00 - mean_squared_error: 1.4070
# [1.406982660293579, 0.0, 1.406982660293579]

# %%
from sklearn.metrics import accuracy_score
y_pred
# Out:
# array([[6.37],
#        [6.61],
#        [6.44],
#        [6.49],
#        [6.74],
#        [6.22],
#        [6.69],
#        [6.18],
#        [6.74],
#        [6.69],
#        [6.17],
#        [6.17],
#        [6.74],
#        [6.44],
#        [6.61],
#        [6.78],
#        [6.3 ],
#        [6.61],
#        [6.46],
#        [6.78],
#        [6.32],
#        [6.61],
#        [6.56],
#        [6.56],
#        [6.61],
#        [6.22],
#        [6.3 ],
#        [6.06],
#        [6.74],
#        [6.46],
#        [6.66],
#        [6.44],
#        [6.22],
#        [6.4 ],
#        [6.27],
#        [6.46],
#        [6.27],
#        [6.17],
#        [6.17],
#        [6.78],
#        [6.18],
#        [6.78],
#        [6.22],
#        [5.98],
#        [6.74],
#        [6.56],
#        [6.61],
#        [6.81],
#        [6.78],
#        [6.81],
#        [6.61],
#        [6.74],
#        [6.43],
#        [6.22],
#        [6.22],
#        [6.78],
#        [6.43],
#        [6.41],
#        [6.81],
#        [6.35],
#        [6.44],
#        [6.58],
#        [6.78],
#        [6.22],
#        [6.74],
#        [6.43],
#        [6.3 ],
#        [6.78],
#        [6.18],
#        [6.35],
#        [6.78],
#        [6.22],
#        [6.37],
#        [6.31],
#        [6.22],
#        [6.74],
#        [6.22],
#        [6.22],
#        [6.2 ],
#        [6.74],
#        [6.44],
#        [6.74],
#        [6.78],
#        [6.22],
#        [6.22],
#        [6.43],
#        [6.74],
#        [6.74],
#        [6.81],
#        [6.43],
#        [6.22],
#        [6.56],
#        [6.61],
#        [6.83],
#        [6.4 ],
#        [6.78],
#        [6.06],
#        [6.32],
#        [6.35],
#        [6.46],
#        [6.58],
#        [6.22],
#        [6.18],
#        [6.61],
#        [6.27],
#        [6.44],
#        [6.18],
#        [6.4 ],
#        [6.56],
#        [6.61],
#        [6.18],
#        [6.43],
#        [6.61],
#        [6.43],
#        [6.35],
#        [6.3 ],
#        [6.22],
#        [6.78],
#        [6.37],
#        [6.22],
#        [6.35],
#        [6.74],
#        [6.61],
#        [6.78],
#        [6.31],
#        [7.13],
#        [6.4 ],
#        [6.43],
#        [6.22],
#        [6.78],
#        [6.22],
#        [6.78],
#        [6.22],
#        [6.81],
#        [6.22],
#        [6.4 ],
#        [6.3 ],
#        [6.78],
#        [6.78],
#        [6.22],
#        [6.35],
#        [6.61],
#        [6.78],
#        [6.12],
#        [6.22],
#        [6.74],
#        [6.18],
#        [6.78],
#        [6.78],
#        [6.06],
#        [6.17],
#        [6.69],
#        [6.44],
#        [6.61],
#        [6.2 ],
#        [6.78],
#        [6.4 ],
#        [6.78],
#        [6.3 ],
#        [6.46],
#        [5.97],
#        [6.56],
#        [6.44],
#        [6.78],
#        [6.06],
#        [6.78],
#        [6.14],
#        [6.61],
#        [7.13],
#        [7.13],
#        [6.22],
#        [6.78],
#        [6.17],
#        [6.81],
#        [6.44],
#        [6.22],
#        [6.81],
#        [6.22],
#        [6.78],
#        [6.18],
#        [6.56],
#        [6.74],
#        [6.61],
#        [6.78],
#        [6.56],
#        [6.35],
#        [6.4 ],
#        [6.37],
#        [6.61],
#        [6.17],
#        [6.61],
#        [6.35],
#        [6.18],
#        [6.43],
#        [6.22],
#        [6.56],
#        [6.74],
#        [6.78],
#        [6.74],
#        [6.78],
#        [6.06],
#        [6.18],
#        [6.18],
#        [6.61],
#        [6.78],
#        [6.61],
#        [6.4 ],
#        [6.4 ],
#        [6.43],
#        [6.78],
#        [6.22],
#        [6.17],
#        [6.78],
#        [6.27],
#        [6.06],
#        [6.22],
#        [6.39],
#        [6.78],
#        [6.4 ],
#        [6.43],
#        [6.78],
#        [6.46],
#        [6.78],
#        [6.35],
#        [6.66],
#        [6.46],
#        [6.22],
#        [6.61],
#        [6.56],
#        [6.61],
#        [6.61],
#        [6.61],
#        [6.78],
#        [6.44],
#        [6.22],
#        [6.46],
#        [6.74],
#        [6.31],
#        [6.49],
#        [6.74],
#        [6.81],
#        [6.78],
#        [6.78],
#        [6.61],
#        [6.06],
#        [6.06],
#        [6.22],
#        [6.61],
#        [6.78],
#        [6.46],
#        [6.74],
#        [6.18],
#        [6.61],
#        [6.18],
#        [6.61],
#        [7.01],
#        [5.98],
#        [6.22],
#        [6.69],
#        [6.61],
#        [6.78],
#        [6.4 ],
#        [6.27],
#        [6.78],
#        [6.22],
#        [6.22],
#        [6.74],
#        [7.1 ],
#        [6.81],
#        [6.78],
#        [6.27],
#        [6.18],
#        [6.06],
#        [6.61],
#        [6.78],
#        [6.61],
#        [6.81],
#        [6.44],
#        [6.81],
#        [6.18],
#        [6.22],
#        [6.44],
#        [6.78],
#        [6.4 ],
#        [6.12],
#        [6.4 ],
#        [6.61],
#        [6.61],
#        [6.22],
#        [6.18],
#        [6.18],
#        [6.18],
#        [6.18],
#        [6.56],
#        [6.29],
#        [6.4 ],
#        [6.22],
#        [7.13],
#        [6.78],
#        [6.4 ],
#        [6.35],
#        [6.37],
#        [6.56],
#        [6.56],
#        [6.12],
#        [6.4 ],
#        [6.78],
#        [6.3 ],
#        [6.37],
#        [6.22],
#        [6.3 ],
#        [6.35],
#        [6.43],
#        [6.22],
#        [6.69],
#        [6.61],
#        [6.22],
#        [6.78],
#        [6.35],
#        [6.22],
#        [6.39],
#        [6.18],
#        [6.78],
#        [6.27],
#        [6.22],
#        [6.2 ],
#        [6.39],
#        [6.61],
#        [6.4 ],
#        [6.4 ],
#        [6.78],
#        [6.43],
#        [6.31],
#        [6.43],
#        [6.35],
#        [7.42],
#        [6.22],
#        [6.78],
#        [6.22],
#        [6.49],
#        [6.22],
#        [6.2 ],
#        [5.98],
#        [6.74],
#        [6.83],
#        [6.49],
#        [6.31],
#        [6.06],
#        [7.13],
#        [6.29],
#        [6.22],
#        [6.5 ],
#        [6.18],
#        [6.74],
#        [6.3 ],
#        [6.35],
#        [6.78],
#        [6.83],
#        [6.43],
#        [6.61],
#        [6.44],
#        [6.74],
#        [6.56],
#        [6.17],
#        [6.22],
#        [6.35],
#        [6.3 ],
#        [6.78],
#        [6.74],
#        [6.56],
#        [6.61],
#        [6.37],
#        [6.22],
#        [6.78],
#        [6.56],
#        [6.27],
#        [6.1 ],
#        [6.22],
#        [6.81],
#        [6.78],
#        [6.18],
#        [6.4 ],
#        [6.74],
#        [6.59],
#        [6.31],
#        [6.18],
#        [6.46],
#        [6.22],
#        [6.74],
#        [6.3 ],
#        [6.74],
#        [6.74],
#        [7.13],
#        [6.61],
#        [6.61],
#        [6.27],
#        [6.43],
#        [6.06],
#        [6.29],
#        [6.78],
#        [6.4 ],
#        [6.18],
#        [6.43],
#        [6.22],
#        [6.18],
#        [6.43],
#        [6.61],
#        [5.98],
#        [6.31],
#        [6.12],
#        [6.22],
#        [6.69],
#        [6.22],
#        [6.27],
#        [6.78],
#        [6.22],
#        [6.41],
#        [6.78],
#        [6.74],
#        [6.56],
#        [6.18],
#        [6.37],
#        [6.74],
#        [6.43],
#        [6.31],
#        [6.22],
#        [6.56],
#        [6.4 ],
#        [6.2 ],
#        [6.74],
#        [6.2 ],
#        [6.61],
#        [6.35],
#        [5.98],
#        [6.74],
#        [6.78],
#        [6.17],
#        [6.78],
#        [6.61],
#        [6.27],
#        [6.61],
#        [6.78],
#        [6.61],
#        [6.27],
#        [6.78],
#        [6.78],
#        [6.78],
#        [6.06],
#        [6.06],
#        [6.78],
#        [6.32],
#        [6.22],
#        [6.78],
#        [5.93],
#        [6.18],
#        [6.74],
#        [6.74],
#        [6.43],
#        [6.61],
#        [6.78],
#        [6.32],
#        [6.18],
#        [6.4 ],
#        [6.14],
#        [6.18],
#        [6.56],
#        [6.58],
#        [6.22],
#        [6.2 ],
#        [6.74],
#        [6.18],
#        [6.22],
#        [6.78],
#        [6.74],
#        [6.22],
#        [5.98],
#        [6.78],
#        [6.56],
#        [6.27],
#        [6.56],
#        [6.46],
#        [6.18],
#        [6.43],
#        [6.78],
#        [6.46],
#        [6.18],
#        [6.43],
#        [6.27],
#        [6.17],
#        [6.61],
#        [6.78],
#        [6.78],
#        [6.78],
#        [6.56],
#        [6.2 ],
#        [6.61],
#        [6.44],
#        [6.37],
#        [6.74],
#        [6.06],
#        [6.35],
#        [6.12],
#        [6.61],
#        [6.31],
#        [6.61],
#        [6.61],
#        [6.14],
#        [6.43],
#        [6.74],
#        [6.27],
#        [6.1 ],
#        [5.98],
#        [6.37],
#        [6.61],
#        [6.22],
#        [6.18],
#        [6.27],
#        [6.22],
#        [6.17],
#        [6.22],
#        [6.31],
#        [6.81],
#        [6.18],
#        [6.22],
#        [5.93],
#        [5.98],
#        [6.4 ],
#        [6.46],
#        [6.78],
#        [6.37],
#        [6.44],
#        [6.78],
#        [6.78],
#        [6.22],
#        [6.4 ],
#        [5.98],
#        [6.81],
#        [6.78],
#        [6.4 ],
#        [6.22],
#        [6.61],
#        [6.78],
#        [6.46],
#        [6.18],
#        [6.2 ],
#        [6.61],
#        [6.18],
#        [6.2 ],
#        [6.22],
#        [6.4 ],
#        [6.23],
#        [6.22],
#        [6.37],
#        [6.74],
#        [6.78],
#        [6.74],
#        [6.17],
#        [6.27],
#        [6.78],
#        [6.78],
#        [6.17],
#        [6.62],
#        [6.78],
#        [6.18],
#        [6.22],
#        [6.43],
#        [6.46],
#        [6.32],
#        [6.37],
#        [6.74],
#        [6.37],
#        [6.43],
#        [6.56],
#        [6.22],
#        [6.61],
#        [6.4 ],
#        [6.78],
#        [6.17],
#        [6.39],
#        [6.56],
#        [6.22],
#        [6.44],
#        [6.66],
#        [6.78],
#        [6.61],
#        [6.2 ],
#        [6.56],
#        [6.78],
#        [6.74],
#        [6.78],
#        [5.93],
#        [6.37],
#        [6.78],
#        [6.74],
#        [6.61],
#        [6.14],
#        [6.61],
#        [6.56],
#        [6.78],
#        [6.78],
#        [6.78],
#        [6.22],
#        [6.78],
#        [6.43],
#        [6.56],
#        [6.44],
#        [6.61],
#        [6.35],
#        [6.22],
#        [6.4 ],
#        [6.43],
#        [6.4 ],
#        [6.18],
#        [6.06],
#        [6.78],
#        [6.22],
#        [6.22],
#        [6.39],
#        [6.61],
#        [6.61],
#        [6.78],
#        [6.35],
#        [6.18],
#        [6.43],
#        [6.43],
#        [6.23],
#        [6.78],
#        [6.56],
#        [6.4 ],
#        [6.46],
#        [6.4 ],
#        [6.4 ],
#        [6.37],
#        [6.61],
#        [6.81],
#        [6.39],
#        [6.74],
#        [6.41],
#        [6.39],
#        [6.22],
#        [5.97],
#        [6.61],
#        [6.4 ],
#        [6.78],
#        [6.22],
#        [6.43],
#        [6.78],
#        [6.35],
#        [6.35],
#        [5.98],
#        [6.66],
#        [6.66],
#        [6.22],
#        [6.61],
#        [6.56],
#        [6.2 ],
#        [6.81],
#        [6.4 ],
#        [6.78],
#        [6.61],
#        [6.61],
#        [6.27],
#        [6.17],
#        [5.98],
#        [6.18],
#        [6.22],
#        [6.79],
#        [6.61],
#        [6.4 ],
#        [6.61],
#        [6.74],
#        [6.56],
#        [6.83],
#        [6.2 ],
#        [6.35],
#        [6.78],
#        [6.56],
#        [6.81],
#        [6.18],
#        [6.61],
#        [6.61],
#        [6.58],
#        [7.66],
#        [6.78],
#        [6.78],
#        [6.61],
#        [6.29],
#        [6.31],
#        [6.49],
#        [6.78],
#        [6.74],
#        [6.49],
#        [6.3 ],
#        [6.31],
#        [6.22],
#        [6.46],
#        [6.74],
#        [6.78],
#        [6.37],
#        [6.27],
#        [6.14],
#        [6.37],
#        [6.58],
#        [6.43],
#        [6.37],
#        [6.43],
#        [6.83],
#        [6.39],
#        [6.2 ],
#        [6.74],
#        [6.27],
#        [6.22],
#        [6.61],
#        [6.78],
#        [6.14],
#        [6.14],
#        [6.44],
#        [6.18],
#        [6.18],
#        [6.22],
#        [6.61],
#        [6.56],
#        [6.61],
#        [6.78],
#        [6.56],
#        [6.78],
#        [6.22],
#        [6.27],
#        [6.74],
#        [6.78],
#        [6.06],
#        [6.74],
#        [6.78],
#        [6.56],
#        [6.22],
#        [6.61],
#        [6.56],
#        [6.78],
#        [6.18],
#        [6.44],
#        [6.06],
#        [6.78],
#        [6.46],
#        [6.78],
#        [6.18],
#        [6.56],
#        [6.22],
#        [6.49],
#        [6.32],
#        [6.43],
#        [6.61],
#        [6.18],
#        [6.56],
#        [6.43],
#        [6.06],
#        [6.61],
#        [6.78],
#        [6.32],
#        [6.78],
#        [6.31],
#        [6.61],
#        [6.22],
#        [6.3 ],
#        [6.81],
#        [6.78],
#        [6.44],
#        [6.61],
#        [6.44],
#        [6.43],
#        [5.93],
#        [6.43],
#        [6.81],
#        [6.61],
#        [6.18],
#        [6.22],
#        [6.18],
#        [6.22],
#        [6.74],
#        [6.32],
#        [6.74],
#        [6.61],
#        [6.43],
#        [6.18],
#        [6.18],
#        [6.74],
#        [6.49],
#        [6.2 ],
#        [6.56],
#        [6.78],
#        [6.22],
#        [6.22],
#        [6.61],
#        [6.61],
#        [6.74],
#        [6.4 ],
#        [6.22],
#        [6.4 ],
#        [6.61],
#        [6.74],
#        [6.78],
#        [6.78],
#        [6.74],
#        [6.44],
#        [6.22],
#        [6.61],
#        [6.61],
#        [6.56],
#        [7.13],
#        [6.3 ],
#        [6.74],
#        [6.46],
#        [6.78],
#        [6.61],
#        [6.27],
#        [6.78],
#        [5.98],
#        [6.78],
#        [6.39],
#        [6.35],
#        [6.78],
#        [5.97],
#        [6.4 ],
#        [6.69],
#        [6.17],
#        [6.22],
#        [6.61],
#        [6.61],
#        [6.18],
#        [6.78],
#        [6.61],
#        [6.22],
#        [6.46],
#        [6.46],
#        [6.43],
#        [6.2 ],
#        [6.2 ],
#        [6.74],
#        [6.06],
#        [6.43],
#        [6.74],
#        [6.78],
#        [6.78],
#        [6.43],
#        [6.61],
#        [6.44],
#        [6.35],
#        [6.61],
#        [6.78],
#        [6.78],
#        [6.41],
#        [5.98],
#        [6.27],
#        [6.56],
#        [6.78],
#        [6.18],
#        [6.32],
#        [6.22],
#        [6.22],
#        [6.61],
#        [6.22],
#        [6.27],
#        [6.61],
#        [6.43],
#        [6.81],
#        [6.81],
#        [5.93],
#        [6.78],
#        [6.22],
#        [6.78],
#        [6.78],
#        [6.78],
#        [6.74],
#        [6.78],
#        [6.4 ],
#        [6.78],
#        [6.4 ],
#        [6.78],
#        [6.78],
#        [6.2 ],
#        [6.56],
#        [6.31],
#        [6.61],
#        [6.44],
#        [7.13],
#        [6.61],
#        [6.56],
#        [7.16],
#        [6.4 ],
#        [6.35],
#        [6.78],
#        [6.18],
#        [6.4 ],
#        [5.92],
#        [6.78],
#        [6.56],
#        [6.56],
#        [6.43],
#        [6.17],
#        [6.83],
#        [6.78]], dtype=float32)

# %%
max(y_pred)
# Out:
# array([7.66], dtype=float32)

# %%
min(y_pred)
# Out:
# array([5.92], dtype=float32)

# %%
plt.hist(y_pred,bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# "etaler" fonction inverse de centrer réduire
